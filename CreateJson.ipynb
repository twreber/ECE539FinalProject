# %%
import json
import os
from google.colab import drive



drive.mount('/content/drive')
with open(os.path.join('/content/drive/My Drive/539Project', 'reviews.json'), 'r', encoding = 'utf-8') as f: 
  N = 25000
  lines = ""
  for i in range(N):
    line = next(f).strip()
    if(i > 0 and i != N - 1):
      lines = lines + '\n' + line + ','
    elif(i == N - 1):
      lines = lines + '\n' + line
    else:
      lines = '[\n' + line + ','
  lines = lines + '\n]'
# Out:
# Mounted at /content/drive

# %%
with open('/content/drive/My Drive/539Project/reviewSmall.json', 'w') as f1:
  f1.write(lines)
